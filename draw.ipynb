# %%
import json


with open('results/agnews/llm_cbm/2025-11-10-19-48-36') as f:
    llm_cbm_alpha_1 = json.load(f)

with open('results/agnews/llm_cbm/2025-11-10-21-51-41') as f:
    llm_cbm_alpha_0 = json.load(f)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.array(llm_cbm_alpha_1) * 0.01, label='with rationale (alpha=1)')
plt.plot(np.array(llm_cbm_alpha_0) * 0.01, label='with rationale (alpha=0)')    # x-axis is implicit: 0,1,2,3...
plt.xlabel("Index")
plt.ylabel("accuracy")
plt.title("Experimental Results")
plt.show()
