# %%
import json


with open('results/agnews/llm_cbm/2025-11-14-02-23-55') as f:
    llm_cbm_alpha_0 = json.load(f)

with open('results/agnews/llm_cbm/2025-11-14-01-30-16') as f:
    llm_cbm_alpha_1 = json.load(f)
    
with open('results/agnews/llm_cbm/2025-11-13-20-44-22') as f:
    llm_cbm_alpha_0_5 = json.load(f)

with open('results/agnews/llm_cbm/2025-11-14-02-40-54') as f:
    llm_cbm_alpha_1_5 = json.load(f)


with open('results/agnews/llm/2025-11-11-05-58-23') as f:
    llm = json.load(f)

# %%
len(llm), len(llm_cbm_alpha_1), llm[81]
# Out:
# (100, 100, 80.23684210526316)

# %%
llm = llm
llm_cbm_alpha_1 = llm_cbm_alpha_1

# %%
import matplotlib.pyplot as plt
import numpy as np

# plt.plot(np.array(llm_cbm_alpha_1) * 0.01, label='with rationale (alpha=1)')
# plt.plot(np.array(llm_cbm_alpha_0) * 0.01, label='with rationale (alpha=0)')
# plt.plot(np.array(llm_cbm_alpha_0_5) * 0.01, label='with rationale (alpha=0.5)')
# plt.plot(np.array(llm_cbm_alpha_1_5) * 0.01, label='with rationale (alpha=1.5)')

plt.plot((np.array(llm_cbm_alpha_1)-np.array(llm_cbm_alpha_0)) * 0.01, label='with rationale (alpha=1)')
plt.plot(np.array([0.]*100))
# plt.plot(np.array(llm) * 0.01, label='without rationale')    # x-axis is implicit: 0,1,2,3...
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()
plt.title("Experimental Results")
txt="Dataset: AG News; Model: DistilBERT; Rationale: LLM; Selection: BADGE"
plt.figtext(0.5, -0.04, txt, wrap=True, horizontalalignment='center', fontsize=12)
plt.show()

# %%
"LLM max accuracy:", max(llm), "\nLLM_with_rationale_alpha_1 max accuracy:", max(llm_cbm_alpha_1)
# Out:
# ('LLM max accuracy:',
#  84.92105263157896,
#  '\nLLM_with_rationale_alpha_1 max accuracy:',
#  86.0657894736842)

# %%
"Final accuracy:", llm[-1], "\nFinal accuracy with rationale (alpha=1):", llm_cbm_alpha_1[-1]
# Out:
# ('Final accuracy:',
#  84.86842105263158,
#  '\nFinal accuracy with rationale (alpha=1):',
#  85.13157894736842)
